# %%
# !pip install geopandas

# Import necessary libraries
import geopandas as gpd

# Load a GeoJSON file containing geospatial data
url = "https://raw.githubusercontent.com/nmota/caop_GeoJSON/master/ContinenteConcelhos.geojson"
portugal = gpd.read_file(url)

# Plot the geospatial data
portugal.plot()
# Out:
# Collecting geopandas
#   Using cached geopandas-1.1.3-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: numpy>=1.24 in /opt/anaconda3/envs/adpro/lib/python3.12/site-packages (from geopandas) (2.4.3)
# Collecting pyogrio>=0.7.2 (from geopandas)
#   Downloading pyogrio-0.12.1-cp312-cp312-macosx_12_0_arm64.whl.metadata (5.9 kB)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/adpro/lib/python3.12/site-packages (from geopandas) (25.0)
# Requirement already satisfied: pandas>=2.0.0 in /opt/anaconda3/envs/adpro/lib/python3.12/site-packages (from geopandas) (3.0.1)
# Collecting pyproj>=3.5.0 (from geopandas)
#   Downloading pyproj-3.7.2-cp312-cp312-macosx_14_0_arm64.whl.metadata (31 kB)
# Collecting shapely>=2.0.0 (from geopandas)
#   Downloading shapely-2.1.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/adpro/lib/python3.12/site-packages (from pandas>=2.0.0->geopandas) (2.9.0.post0)
# Collecting certifi (from pyogrio>=0.7.2->geopandas)
#   Using cached certifi-2026.2.25-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/adpro/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->geopandas) (1.17.0)
# Using cached geopandas-1.1.3-py3-none-any.whl (342 kB)
# Downloading pyogrio-0.12.1-cp312-cp312-macosx_12_0_arm64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 57.8 MB/s  0:00:00m0:00:0100:01
# Downloading pyproj-3.7.2-cp312-cp312-macosx_14_0_arm64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 61.7 MB/s  0:00:00
# Downloading shapely-2.1.2-cp312-cp312-macosx_11_0_arm64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 49.0 MB/s  0:00:00
# Using cached certifi-2026.2.25-py3-none-any.whl (153 kB)
# Installing collected packages: shapely, certifi, pyproj, pyogrio, geopandas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [geopandas]/5 [geopandas]
# Successfully installed certifi-2026.2.25 geopandas-1.1.3 pyogrio-0.12.1 pyproj-3.7.2 shapely-2.1.2
# <Axes: >
